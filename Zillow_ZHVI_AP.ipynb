# %%
import pandas as pd

# %%
df_zhvi = pd.read_csv("Metro_zhvi_sm_sa_month.csv", skiprows=[1])
df_zhvi.head()
# Out:
#    RegionID  SizeRank                          RegionName RegionType  \
# 0    394913         1                        New York, NY        Msa
# 1    753899         2  Los Angeles-Long Beach-Anaheim, CA        Msa
# 2    394463         3                         Chicago, IL        Msa
# 3    394514         4               Dallas-Fort Worth, TX        Msa
# 4    394974         5                    Philadelphia, PA        Msa
#
#   StateName  2000-01-31  2000-02-29  2000-03-31  2000-04-30  2000-05-31  ...  \
# 0        NY    225516.0    226863.0    228076.0    230462.0    232684.0  ...
# 1        CA    231193.0    231998.0    233231.0    235575.0    238089.0  ...
# 2        IL    171271.0    171675.0    172198.0    173245.0    174354.0  ...
# 3        TX    131555.0    131660.0    131748.0    131961.0    132186.0  ...
# 4        PA    130664.0    131102.0    131365.0    132019.0    132548.0  ...
#
#    2021-09-30  2021-10-31  2021-11-30  2021-12-31  2022-01-31  2022-02-28  \
# ...

# %%
df_zhvi.shape
# Out:
# (907, 275)

# %%
df_zhvi.describe()
# Out:
#             RegionID    SizeRank     2000-01-31     2000-02-29     2000-03-31  \
# count     907.000000  907.000000     441.000000     442.000000     443.000000
# mean   415362.621830  458.314223  111778.011338  112093.617647  112331.101580
# std     83534.501875  267.468546   53431.111974   53609.993189   53867.527434
# min    394297.000000    1.000000   34637.000000   34540.000000   34582.000000
# 25%    394549.500000  227.500000   76892.000000   77166.500000   77393.000000
# 50%    394805.000000  454.000000   99932.000000  100481.500000  100350.000000
# 75%    395052.000000  686.500000  130664.000000  130645.750000  130591.000000
# max    753929.000000  933.000000  434391.000000  436998.000000  440726.000000
#
#           2000-04-30     2000-05-31     2000-06-30     2000-07-31  \
# count     445.000000     447.000000     448.000000     449.000000
# mean   113175.939326  114006.814318  114535.830357  115242.314031
# std     54778.562436   55545.817953   56324.784252   57081.485879
# ...

# %%
#Add a column for Region

df_zhvi.loc[(df_zhvi['StateName'] == 'CT') | (df_zhvi['StateName'] == 'ME') | (df_zhvi['StateName'] == 'MA') 
            | (df_zhvi['StateName'] == 'NH') | (df_zhvi['StateName'] == 'RI') | (df_zhvi['StateName'] == 'VT')
            | (df_zhvi['StateName'] == 'NJ')| (df_zhvi['StateName'] == 'NY')| (df_zhvi['StateName'] == 'PA'),
            'Region'] = 'North East'

df_zhvi.loc[(df_zhvi['StateName'] == 'IL') | (df_zhvi['StateName'] == 'IN') | (df_zhvi['StateName'] == 'MI') 
            | (df_zhvi['StateName'] == 'OH') | (df_zhvi['StateName'] == 'WI') | (df_zhvi['StateName'] == 'IA')
            | (df_zhvi['StateName'] == 'KS')| (df_zhvi['StateName'] == 'MN')| (df_zhvi['StateName'] == 'MO')
            | (df_zhvi['StateName'] == 'NE')| (df_zhvi['StateName'] == 'ND')| (df_zhvi['StateName'] == 'SD'),
            'Region'] = 'Mid West'

df_zhvi.loc[(df_zhvi['StateName'] == 'DE') | (df_zhvi['StateName'] == 'DC') | (df_zhvi['StateName'] == 'FL') 
            | (df_zhvi['StateName'] == 'GA') | (df_zhvi['StateName'] == 'MD') | (df_zhvi['StateName'] == 'NC')
            | (df_zhvi['StateName'] == 'SC')| (df_zhvi['StateName'] == 'VA')| (df_zhvi['StateName'] == 'WV')
            | (df_zhvi['StateName'] == 'AL')| (df_zhvi['StateName'] == 'KY')| (df_zhvi['StateName'] == 'MS')
            | (df_zhvi['StateName'] == 'TN')| (df_zhvi['StateName'] == 'AR')| (df_zhvi['StateName'] == 'LA')
            | (df_zhvi['StateName'] == 'OK')| (df_zhvi['StateName'] == 'TX'),
            'Region'] = 'South'

df_zhvi.loc[(df_zhvi['StateName'] == 'AZ') | (df_zhvi['StateName'] == 'CA') | (df_zhvi['StateName'] == 'CO') 
            | (df_zhvi['StateName'] == 'ID') | (df_zhvi['StateName'] == 'MT') | (df_zhvi['StateName'] == 'NV')
            | (df_zhvi['StateName'] == 'NM')| (df_zhvi['StateName'] == 'OR')| (df_zhvi['StateName'] == 'UT')
            | (df_zhvi['StateName'] == 'WA')| (df_zhvi['StateName'] == 'WY')| (df_zhvi['StateName'] == 'AK')
            | (df_zhvi['StateName'] == 'HI'),
            'Region'] = 'West'

df_zhvi.head(10)
# Out:
#    RegionID  SizeRank                          RegionName RegionType  \
# 0    394913         1                        New York, NY        Msa
# 1    753899         2  Los Angeles-Long Beach-Anaheim, CA        Msa
# 2    394463         3                         Chicago, IL        Msa
# 3    394514         4               Dallas-Fort Worth, TX        Msa
# 4    394974         5                    Philadelphia, PA        Msa
# 5    394692         6                         Houston, TX        Msa
# 6    395209         7                      Washington, DC        Msa
# 7    394856         8           Miami-Fort Lauderdale, FL        Msa
# 8    394347         9                         Atlanta, GA        Msa
# 9    394404        10                          Boston, MA        Msa
#
#   StateName  2000-01-31  2000-02-29  2000-03-31  2000-04-30  2000-05-31  ...  \
# 0        NY    225516.0    226863.0    228076.0    230462.0    232684.0  ...
# ...

# %%
df_zhvi.isnull().sum()
# Out:
# RegionID      0
# SizeRank      0
# RegionName    0
# RegionType    0
# StateName     0
#              ..
# 2022-03-31    2
# 2022-04-30    0
# 2022-05-31    0
# 2022-06-30    0
# Region        0
# Length: 276, dtype: int64

# %%
#using melt function to reshape the dataframe into pivot

df_zhvi_melt = pd.melt(df_zhvi , id_vars = ['RegionID','SizeRank','RegionName','RegionType','StateName','Region'] , var_name='Date' , value_name='ZHVI' )
df_zhvi_melt.head()
# Out:
#    RegionID  SizeRank                          RegionName RegionType  \
# 0    394913         1                        New York, NY        Msa
# 1    753899         2  Los Angeles-Long Beach-Anaheim, CA        Msa
# 2    394463         3                         Chicago, IL        Msa
# 3    394514         4               Dallas-Fort Worth, TX        Msa
# 4    394974         5                    Philadelphia, PA        Msa
#
#   StateName      Region        Date      ZHVI
# 0        NY  North East  2000-01-31  225516.0
# 1        CA        West  2000-01-31  231193.0
# 2        IL    Mid West  2000-01-31  171271.0
# 3        TX       South  2000-01-31  131555.0
# 4        PA  North East  2000-01-31  130664.0

# %%
df_zhvi_melt.tail()
# Out:
#         RegionID  SizeRank     RegionName RegionType StateName Region  \
# 244885    394767       929     Lamesa, TX        Msa        TX  South
# 244886    753874       930      Craig, CO        Msa        CO   West
# 244887    394968       931      Pecos, TX        Msa        TX  South
# 244888    395188       932     Vernon, TX        Msa        TX  South
# 244889    394743       933  Ketchikan, AK        Msa        AK   West
#
#               Date      ZHVI
# 244885  2022-06-30  102796.0
# 244886  2022-06-30  259578.0
# 244887  2022-06-30  190000.0
# 244888  2022-06-30   89621.0
# 244889  2022-06-30  363980.0

# %%
df_zhvi_melt.shape
# Out:
# (244890, 8)

# %%
df_zhvi_melt.isnull().sum()
# Out:
# RegionID          0
# SizeRank          0
# RegionName        0
# RegionType        0
# StateName         0
# Region            0
# Date              0
# ZHVI          50519
# dtype: int64

# %%
df_zhvi_melt.rename(columns={'RegionName':'City/MSA' , 'StateName':'State'})
# Out:
#         RegionID  SizeRank                            City/MSA RegionType  \
# 0         394913         1                        New York, NY        Msa
# 1         753899         2  Los Angeles-Long Beach-Anaheim, CA        Msa
# 2         394463         3                         Chicago, IL        Msa
# 3         394514         4               Dallas-Fort Worth, TX        Msa
# 4         394974         5                    Philadelphia, PA        Msa
# ...          ...       ...                                 ...        ...
# 244885    394767       929                          Lamesa, TX        Msa
# 244886    753874       930                           Craig, CO        Msa
# 244887    394968       931                           Pecos, TX        Msa
# 244888    395188       932                          Vernon, TX        Msa
# 244889    394743       933                       Ketchikan, AK        Msa
#
#        State      Region        Date      ZHVI
# ...

# %%
#Exploring data

df_zhvi_melt[df_zhvi_melt['Date']=='2022-06-30']
# Out:
#         RegionID  SizeRank                          RegionName RegionType  \
# 243983    394913         1                        New York, NY        Msa
# 243984    753899         2  Los Angeles-Long Beach-Anaheim, CA        Msa
# 243985    394463         3                         Chicago, IL        Msa
# 243986    394514         4               Dallas-Fort Worth, TX        Msa
# 243987    394974         5                    Philadelphia, PA        Msa
# ...          ...       ...                                 ...        ...
# 244885    394767       929                          Lamesa, TX        Msa
# 244886    753874       930                           Craig, CO        Msa
# 244887    394968       931                           Pecos, TX        Msa
# 244888    395188       932                          Vernon, TX        Msa
# 244889    394743       933                       Ketchikan, AK        Msa
#
#        StateName      Region        Date      ZHVI
# ...

# %%
df_zhvi_melt.to_csv(r'C:\Users\apuri\Desktop\Python\ZHVIdatawithpivot.csv', index = False)
